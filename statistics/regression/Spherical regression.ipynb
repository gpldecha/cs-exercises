# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
phi = np.linspace(0, np.pi, 15)
theta = np.linspace(0, 2*np.pi, 30)
phi, theta = np.meshgrid(phi, theta)

# The Cartesian coordinates of the unit sphere
x = np.sin(phi)*np.cos(theta)
y = np.sin(phi)*np.sin(theta)
z = np.cos(phi)

# %%
# Set the aspect ratio to 1 so our sphere looks spherical
fig, ax = plt.subplots(1, 1, subplot_kw={'projection':'3d', 'aspect':'equal'})
surf = ax.plot_surface(x, y, z)
surf.set_edgecolors("black")
# Turn off the axis planes
#ax.set_axis_off()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
def direction2polar(direction):
    return np.array([np.arctan(direction[1]/direction[0]), np.arcos(direction[2])])

# %% [markdown]
# ### Generate test data
# https://hal.archives-ouvertes.fr/hal-01119942v1/document
